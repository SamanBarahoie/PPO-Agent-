# %%
# !pip install numpy==1.23.5

# %%
# !pip install gym==0.26.2

# %%
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time

# %% [markdown]
# # ActorCritic

# %%
class ActorCritic(nn.Module):
    def __init__(self, input_dim, action_dim):
        super(ActorCritic, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU()
        )
        self.policy_head = nn.Linear(64, action_dim)
        self.value_head = nn.Linear(64, 1)

    def forward(self, state):
        x = self.shared(state)
        logits = self.policy_head(x)
        value = self.value_head(x)
        probs = F.softmax(logits, dim=-1)
        return probs, value.squeeze(-1)

    def act(self, state):
        probs, value = self.forward(state)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample()
        return action.item(), dist.log_prob(action), value

# %% [markdown]
# # PPOAgent

# %%
class PPOAgent:
    def __init__(self, state_dim, action_dim, lr=3e-4, gamma=0.99, lam=0.95, clip_eps=0.2, epochs=10, batch_size=64):
        self.model = ActorCritic(state_dim, action_dim)
        self.optimizer = optim.Adam(self.model.parameters(), lr=lr)
        self.buffer = RolloutBuffer()
        self.gamma = gamma
        self.lam = lam
        self.clip_eps = clip_eps
        self.epochs = epochs
        self.batch_size = batch_size

    def select_action(self, state):
        state = torch.FloatTensor(state).unsqueeze(0)
        action, log_prob, value = self.model.act(state)
        return action, log_prob.item(), value.item()

    def store_transition(self, *args):
        self.buffer.add(*args)

    def update(self):
        self.buffer.compute_returns_and_advantages(self.gamma, self.lam)

        for _ in range(self.epochs):
            for states, actions, old_log_probs, returns, advantages in self.buffer.get_batches(self.batch_size):
                probs, values = self.model(states)
                dist = torch.distributions.Categorical(probs)
                entropy = dist.entropy().mean()
                new_log_probs = dist.log_prob(actions)

                ratio = torch.exp(new_log_probs - old_log_probs)
                surr1 = ratio * advantages
                surr2 = torch.clamp(ratio, 1 - self.clip_eps, 1 + self.clip_eps) * advantages
                policy_loss = -torch.min(surr1, surr2).mean()

                value_loss = F.mse_loss(values, returns)

                loss = policy_loss + 0.5 * value_loss - 0.01 * entropy

                self.optimizer.zero_grad()
                loss.backward()
                self.optimizer.step()

        self.buffer.clear()

# %% [markdown]
# # RolloutBuffer

# %%
class RolloutBuffer:
    def __init__(self):
        self.states = []
        self.actions = []
        self.log_probs = []
        self.rewards = []
        self.dones = []
        self.values = []

    def add(self, state, action, log_prob, reward, done, value):
        self.states.append(state)
        self.actions.append(action)
        self.log_probs.append(log_prob)
        self.rewards.append(reward)
        self.dones.append(done)
        self.values.append(value)

    def compute_returns_and_advantages(self, gamma=0.99, lam=0.95):
        returns = []
        advantages = []
        gae = 0
        next_value = 0

        for i in reversed(range(len(self.rewards))):
            delta = self.rewards[i] + gamma * next_value * (1 - self.dones[i]) - self.values[i]
            gae = delta + gamma * lam * (1 - self.dones[i]) * gae
            next_value = self.values[i]
            returns.insert(0, gae + self.values[i])
            advantages.insert(0, gae)

        self.returns = returns
        self.advantages = advantages

    def get_batches(self, batch_size):
        total = len(self.states)
        indices = np.arange(total)
        np.random.shuffle(indices)

        for start in range(0, total, batch_size):
            end = start + batch_size
            batch_indices = indices[start:end]
            yield (
                torch.FloatTensor(np.array(self.states)[batch_indices]),
                torch.LongTensor(np.array(self.actions)[batch_indices]),
                torch.FloatTensor(np.array(self.log_probs)[batch_indices]),
                torch.FloatTensor(np.array(self.returns)[batch_indices]),
                torch.FloatTensor(np.array(self.advantages)[batch_indices])
            )

    def clear(self):
        self.__init__()

# %% [markdown]
# #train

# %%
import numpy as np
# --- اموزش ---
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, _ = env.reset()
state_dim = obs.shape[0]
action_dim = env.action_space.n

agent = PPOAgent(state_dim, action_dim)


max_episodes = 1000
max_steps = 500
reward_history = []

for episode in range(max_episodes):
    state = env.reset()
    if isinstance(state, tuple):  # سازگاری با نسخه‌های مختلف gym
        state = state[0]
    total_reward = 0

    for _ in range(max_steps):
        action, log_prob, value = agent.select_action(state)
        next_state, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated
        total_reward += reward
        agent.store_transition(state, action, log_prob, reward, done, value)
        state = next_state
        if done:
            break

    agent.update()
    reward_history.append(total_reward)

    # میانگین متحرک 100 اپیزود اخیر
    if len(reward_history) >= 100:
        moving_avg = np.mean(reward_history[-100:])
    else:
        moving_avg = np.mean(reward_history)

    print(f"Episode {episode+1}, Reward: {total_reward:.1f}, Moving Avg (100): {moving_avg:.2f}")

    # چک کردن موفقیت
    if moving_avg >= 475.0:
        print(f"[+] Environment solved in {episode+1} episodes!")
        break
# Out:
# Episode 1, Reward: 23.0, Moving Avg (100): 23.00
# Episode 2, Reward: 24.0, Moving Avg (100): 23.50
# Episode 3, Reward: 22.0, Moving Avg (100): 23.00
# Episode 4, Reward: 18.0, Moving Avg (100): 21.75
# Episode 5, Reward: 12.0, Moving Avg (100): 19.80
# Episode 6, Reward: 21.0, Moving Avg (100): 20.00
# Episode 7, Reward: 9.0, Moving Avg (100): 18.43
# Episode 8, Reward: 21.0, Moving Avg (100): 18.75
# Episode 9, Reward: 21.0, Moving Avg (100): 19.00
# Episode 10, Reward: 33.0, Moving Avg (100): 20.40
# Episode 11, Reward: 44.0, Moving Avg (100): 22.55
# Episode 12, Reward: 38.0, Moving Avg (100): 23.83
# Episode 13, Reward: 19.0, Moving Avg (100): 23.46
# Episode 14, Reward: 28.0, Moving Avg (100): 23.79
# Episode 15, Reward: 27.0, Moving Avg (100): 24.00
# Episode 16, Reward: 26.0, Moving Avg (100): 24.12
# Episode 17, Reward: 42.0, Moving Avg (100): 25.18
# Episode 18, Reward: 20.0, Moving Avg (100): 24.89
# Episode 19, Reward: 59.0, Moving Avg (100): 26.68
# Episode 20, Reward: 46.0, Moving Avg (100): 27.65
# Episode 21, Reward: 41.0, Moving Avg (100): 28.29
# Episode 22, Reward: 13.0, Moving Avg (100): 27.59
# Episode 23, Reward: 10.0, Moving Avg (100): 26.83
# Episode 24, Reward: 50.0, Moving Avg (100): 27.79
# Episode 25, Reward: 20.0, Moving Avg (100): 27.48
# Episode 26, Reward: 13.0, Moving Avg (100): 26.92
# Episode 27, Reward: 18.0, Moving Avg (100): 26.59
# Episode 28, Reward: 12.0, Moving Avg (100): 26.07
# Episode 29, Reward: 11.0, Moving Avg (100): 25.55
# Episode 30, Reward: 11.0, Moving Avg (100): 25.07
# Episode 31, Reward: 11.0, Moving Avg (100): 24.61
# Episode 32, Reward: 11.0, Moving Avg (100): 24.19
# Episode 33, Reward: 15.0, Moving Avg (100): 23.91
# Episode 34, Reward: 13.0, Moving Avg (100): 23.59
# Episode 35, Reward: 10.0, Moving Avg (100): 23.20
# Episode 36, Reward: 20.0, Moving Avg (100): 23.11
# Episode 37, Reward: 13.0, Moving Avg (100): 22.84
# Episode 38, Reward: 11.0, Moving Avg (100): 22.53
# Episode 39, Reward: 14.0, Moving Avg (100): 22.31
# Episode 40, Reward: 11.0, Moving Avg (100): 22.02
# Episode 41, Reward: 21.0, Moving Avg (100): 22.00
# Episode 42, Reward: 11.0, Moving Avg (100): 21.74
# Episode 43, Reward: 19.0, Moving Avg (100): 21.67
# Episode 44, Reward: 16.0, Moving Avg (100): 21.55
# Episode 45, Reward: 23.0, Moving Avg (100): 21.58
# Episode 46, Reward: 9.0, Moving Avg (100): 21.30
# Episode 47, Reward: 32.0, Moving Avg (100): 21.53
# Episode 48, Reward: 28.0, Moving Avg (100): 21.67
# Episode 49, Reward: 27.0, Moving Avg (100): 21.78
# Episode 50, Reward: 23.0, Moving Avg (100): 21.80
# Episode 51, Reward: 30.0, Moving Avg (100): 21.96
# Episode 52, Reward: 23.0, Moving Avg (100): 21.98
# Episode 53, Reward: 16.0, Moving Avg (100): 21.87
# Episode 54, Reward: 16.0, Moving Avg (100): 21.76
# Episode 55, Reward: 13.0, Moving Avg (100): 21.60
# Episode 56, Reward: 15.0, Moving Avg (100): 21.48
# Episode 57, Reward: 30.0, Moving Avg (100): 21.63
# Episode 58, Reward: 26.0, Moving Avg (100): 21.71
# Episode 59, Reward: 11.0, Moving Avg (100): 21.53
# Episode 60, Reward: 30.0, Moving Avg (100): 21.67
# Episode 61, Reward: 19.0, Moving Avg (100): 21.62
# Episode 62, Reward: 38.0, Moving Avg (100): 21.89
# Episode 63, Reward: 34.0, Moving Avg (100): 22.08
# Episode 64, Reward: 14.0, Moving Avg (100): 21.95
# Episode 65, Reward: 14.0, Moving Avg (100): 21.83
# Episode 66, Reward: 17.0, Moving Avg (100): 21.76
# Episode 67, Reward: 24.0, Moving Avg (100): 21.79
# Episode 68, Reward: 43.0, Moving Avg (100): 22.10
# Episode 69, Reward: 16.0, Moving Avg (100): 22.01
# Episode 70, Reward: 57.0, Moving Avg (100): 22.51
# Episode 71, Reward: 16.0, Moving Avg (100): 22.42
# Episode 72, Reward: 23.0, Moving Avg (100): 22.43
# Episode 73, Reward: 11.0, Moving Avg (100): 22.27
# Episode 74, Reward: 43.0, Moving Avg (100): 22.55
# Episode 75, Reward: 71.0, Moving Avg (100): 23.20
# Episode 76, Reward: 47.0, Moving Avg (100): 23.51
# Episode 77, Reward: 28.0, Moving Avg (100): 23.57
# Episode 78, Reward: 22.0, Moving Avg (100): 23.55
# Episode 79, Reward: 16.0, Moving Avg (100): 23.46
# Episode 80, Reward: 36.0, Moving Avg (100): 23.61
# Episode 81, Reward: 19.0, Moving Avg (100): 23.56
# Episode 82, Reward: 16.0, Moving Avg (100): 23.46
# Episode 83, Reward: 14.0, Moving Avg (100): 23.35
# Episode 84, Reward: 18.0, Moving Avg (100): 23.29
# Episode 85, Reward: 15.0, Moving Avg (100): 23.19
# Episode 86, Reward: 17.0, Moving Avg (100): 23.12
# Episode 87, Reward: 21.0, Moving Avg (100): 23.09
# Episode 88, Reward: 35.0, Moving Avg (100): 23.23
# Episode 89, Reward: 84.0, Moving Avg (100): 23.91
# Episode 90, Reward: 35.0, Moving Avg (100): 24.03
# Episode 91, Reward: 26.0, Moving Avg (100): 24.05
# Episode 92, Reward: 49.0, Moving Avg (100): 24.33
# Episode 93, Reward: 54.0, Moving Avg (100): 24.65
# Episode 94, Reward: 64.0, Moving Avg (100): 25.06
# Episode 95, Reward: 42.0, Moving Avg (100): 25.24
# Episode 96, Reward: 19.0, Moving Avg (100): 25.18
# Episode 97, Reward: 36.0, Moving Avg (100): 25.29
# Episode 98, Reward: 32.0, Moving Avg (100): 25.36
# Episode 99, Reward: 58.0, Moving Avg (100): 25.69
# Episode 100, Reward: 65.0, Moving Avg (100): 26.08
# Episode 101, Reward: 23.0, Moving Avg (100): 26.08
# Episode 102, Reward: 17.0, Moving Avg (100): 26.01
# Episode 103, Reward: 100.0, Moving Avg (100): 26.79
# Episode 104, Reward: 31.0, Moving Avg (100): 26.92
# Episode 105, Reward: 64.0, Moving Avg (100): 27.44
# Episode 106, Reward: 68.0, Moving Avg (100): 27.91
# Episode 107, Reward: 36.0, Moving Avg (100): 28.18
# Episode 108, Reward: 19.0, Moving Avg (100): 28.16
# Episode 109, Reward: 195.0, Moving Avg (100): 29.90
# Episode 110, Reward: 67.0, Moving Avg (100): 30.24
# Episode 111, Reward: 39.0, Moving Avg (100): 30.19
# Episode 112, Reward: 47.0, Moving Avg (100): 30.28
# Episode 113, Reward: 31.0, Moving Avg (100): 30.40
# Episode 114, Reward: 47.0, Moving Avg (100): 30.59
# Episode 115, Reward: 122.0, Moving Avg (100): 31.54
# Episode 116, Reward: 58.0, Moving Avg (100): 31.86
# Episode 117, Reward: 47.0, Moving Avg (100): 31.91
# Episode 118, Reward: 33.0, Moving Avg (100): 32.04
# Episode 119, Reward: 23.0, Moving Avg (100): 31.68
# Episode 120, Reward: 166.0, Moving Avg (100): 32.88
# Episode 121, Reward: 136.0, Moving Avg (100): 33.83
# Episode 122, Reward: 25.0, Moving Avg (100): 33.95
# Episode 123, Reward: 21.0, Moving Avg (100): 34.06
# Episode 124, Reward: 78.0, Moving Avg (100): 34.34
# Episode 125, Reward: 82.0, Moving Avg (100): 34.96
# Episode 126, Reward: 36.0, Moving Avg (100): 35.19
# Episode 127, Reward: 150.0, Moving Avg (100): 36.51
# Episode 128, Reward: 84.0, Moving Avg (100): 37.23
# Episode 129, Reward: 52.0, Moving Avg (100): 37.64
# Episode 130, Reward: 27.0, Moving Avg (100): 37.80
# Episode 131, Reward: 21.0, Moving Avg (100): 37.90
# Episode 132, Reward: 39.0, Moving Avg (100): 38.18
# Episode 133, Reward: 37.0, Moving Avg (100): 38.40
# Episode 134, Reward: 54.0, Moving Avg (100): 38.81
# Episode 135, Reward: 114.0, Moving Avg (100): 39.85
# Episode 136, Reward: 92.0, Moving Avg (100): 40.57
# Episode 137, Reward: 133.0, Moving Avg (100): 41.77
# Episode 138, Reward: 32.0, Moving Avg (100): 41.98
# Episode 139, Reward: 99.0, Moving Avg (100): 42.83
# Episode 140, Reward: 94.0, Moving Avg (100): 43.66
# Episode 141, Reward: 22.0, Moving Avg (100): 43.67
# Episode 142, Reward: 18.0, Moving Avg (100): 43.74
# Episode 143, Reward: 167.0, Moving Avg (100): 45.22
# Episode 144, Reward: 117.0, Moving Avg (100): 46.23
# Episode 145, Reward: 27.0, Moving Avg (100): 46.27
# Episode 146, Reward: 35.0, Moving Avg (100): 46.53
# Episode 147, Reward: 57.0, Moving Avg (100): 46.78
# Episode 148, Reward: 136.0, Moving Avg (100): 47.86
# Episode 149, Reward: 191.0, Moving Avg (100): 49.50
# Episode 150, Reward: 125.0, Moving Avg (100): 50.52
# Episode 151, Reward: 35.0, Moving Avg (100): 50.57
# Episode 152, Reward: 51.0, Moving Avg (100): 50.85
# Episode 153, Reward: 129.0, Moving Avg (100): 51.98
# Episode 154, Reward: 52.0, Moving Avg (100): 52.34
# Episode 155, Reward: 12.0, Moving Avg (100): 52.33
# Episode 156, Reward: 26.0, Moving Avg (100): 52.44
# Episode 157, Reward: 26.0, Moving Avg (100): 52.40
# Episode 158, Reward: 27.0, Moving Avg (100): 52.41
# Episode 159, Reward: 31.0, Moving Avg (100): 52.61
# Episode 160, Reward: 65.0, Moving Avg (100): 52.96
# Episode 161, Reward: 47.0, Moving Avg (100): 53.24
# Episode 162, Reward: 108.0, Moving Avg (100): 53.94
# Episode 163, Reward: 44.0, Moving Avg (100): 54.04
# Episode 164, Reward: 27.0, Moving Avg (100): 54.17
# Episode 165, Reward: 154.0, Moving Avg (100): 55.57
# Episode 166, Reward: 179.0, Moving Avg (100): 57.19
# Episode 167, Reward: 154.0, Moving Avg (100): 58.49
# Episode 168, Reward: 41.0, Moving Avg (100): 58.47
# Episode 169, Reward: 101.0, Moving Avg (100): 59.32
# Episode 170, Reward: 108.0, Moving Avg (100): 59.83
# Episode 171, Reward: 40.0, Moving Avg (100): 60.07
# Episode 172, Reward: 219.0, Moving Avg (100): 62.03
# Episode 173, Reward: 27.0, Moving Avg (100): 62.19
# Episode 174, Reward: 22.0, Moving Avg (100): 61.98
# Episode 175, Reward: 25.0, Moving Avg (100): 61.52
# Episode 176, Reward: 106.0, Moving Avg (100): 62.11
# Episode 177, Reward: 59.0, Moving Avg (100): 62.42
# Episode 178, Reward: 129.0, Moving Avg (100): 63.49
# Episode 179, Reward: 41.0, Moving Avg (100): 63.74
# Episode 180, Reward: 125.0, Moving Avg (100): 64.63
# Episode 181, Reward: 180.0, Moving Avg (100): 66.24
# Episode 182, Reward: 92.0, Moving Avg (100): 67.00
# Episode 183, Reward: 91.0, Moving Avg (100): 67.77
# Episode 184, Reward: 34.0, Moving Avg (100): 67.93
# Episode 185, Reward: 154.0, Moving Avg (100): 69.32
# Episode 186, Reward: 27.0, Moving Avg (100): 69.42
# Episode 187, Reward: 159.0, Moving Avg (100): 70.80
# Episode 188, Reward: 479.0, Moving Avg (100): 75.24
# Episode 189, Reward: 136.0, Moving Avg (100): 75.76
# Episode 190, Reward: 47.0, Moving Avg (100): 75.88
# Episode 191, Reward: 99.0, Moving Avg (100): 76.61
# Episode 192, Reward: 259.0, Moving Avg (100): 78.71
# Episode 193, Reward: 137.0, Moving Avg (100): 79.54
# Episode 194, Reward: 45.0, Moving Avg (100): 79.35
# Episode 195, Reward: 125.0, Moving Avg (100): 80.18
# Episode 196, Reward: 252.0, Moving Avg (100): 82.51
# Episode 197, Reward: 159.0, Moving Avg (100): 83.74
# Episode 198, Reward: 30.0, Moving Avg (100): 83.72
# Episode 199, Reward: 42.0, Moving Avg (100): 83.56
# Episode 200, Reward: 82.0, Moving Avg (100): 83.73
# Episode 201, Reward: 208.0, Moving Avg (100): 85.58
# Episode 202, Reward: 207.0, Moving Avg (100): 87.48
# Episode 203, Reward: 137.0, Moving Avg (100): 87.85
# Episode 204, Reward: 28.0, Moving Avg (100): 87.82
# Episode 205, Reward: 60.0, Moving Avg (100): 87.78
# Episode 206, Reward: 21.0, Moving Avg (100): 87.31
# Episode 207, Reward: 185.0, Moving Avg (100): 88.80
# Episode 208, Reward: 117.0, Moving Avg (100): 89.78
# Episode 209, Reward: 122.0, Moving Avg (100): 89.05
# Episode 210, Reward: 234.0, Moving Avg (100): 90.72
# Episode 211, Reward: 153.0, Moving Avg (100): 91.86
# Episode 212, Reward: 161.0, Moving Avg (100): 93.00
# Episode 213, Reward: 98.0, Moving Avg (100): 93.67
# Episode 214, Reward: 267.0, Moving Avg (100): 95.87
# Episode 215, Reward: 121.0, Moving Avg (100): 95.86
# Episode 216, Reward: 50.0, Moving Avg (100): 95.78
# Episode 217, Reward: 230.0, Moving Avg (100): 97.61
# Episode 218, Reward: 219.0, Moving Avg (100): 99.47
# Episode 219, Reward: 41.0, Moving Avg (100): 99.65
# Episode 220, Reward: 107.0, Moving Avg (100): 99.06
# Episode 221, Reward: 131.0, Moving Avg (100): 99.01
# Episode 222, Reward: 126.0, Moving Avg (100): 100.02
# Episode 223, Reward: 180.0, Moving Avg (100): 101.61
# Episode 224, Reward: 31.0, Moving Avg (100): 101.14
# Episode 225, Reward: 202.0, Moving Avg (100): 102.34
# Episode 226, Reward: 141.0, Moving Avg (100): 103.39
# Episode 227, Reward: 201.0, Moving Avg (100): 103.90
# Episode 228, Reward: 187.0, Moving Avg (100): 104.93
# Episode 229, Reward: 49.0, Moving Avg (100): 104.90
# Episode 230, Reward: 66.0, Moving Avg (100): 105.29
# Episode 231, Reward: 37.0, Moving Avg (100): 105.45
# Episode 232, Reward: 138.0, Moving Avg (100): 106.44
# Episode 233, Reward: 164.0, Moving Avg (100): 107.71
# Episode 234, Reward: 376.0, Moving Avg (100): 110.93
# Episode 235, Reward: 100.0, Moving Avg (100): 110.79
# Episode 236, Reward: 35.0, Moving Avg (100): 110.22
# Episode 237, Reward: 220.0, Moving Avg (100): 111.09
# Episode 238, Reward: 169.0, Moving Avg (100): 112.46
# Episode 239, Reward: 29.0, Moving Avg (100): 111.76
# Episode 240, Reward: 23.0, Moving Avg (100): 111.05
# Episode 241, Reward: 27.0, Moving Avg (100): 111.10
# Episode 242, Reward: 33.0, Moving Avg (100): 111.25
# Episode 243, Reward: 232.0, Moving Avg (100): 111.90
# Episode 244, Reward: 235.0, Moving Avg (100): 113.08
# Episode 245, Reward: 442.0, Moving Avg (100): 117.23
# Episode 246, Reward: 153.0, Moving Avg (100): 118.41
# Episode 247, Reward: 37.0, Moving Avg (100): 118.21
# Episode 248, Reward: 43.0, Moving Avg (100): 117.28
# Episode 249, Reward: 178.0, Moving Avg (100): 117.15
# Episode 250, Reward: 425.0, Moving Avg (100): 120.15
# Episode 251, Reward: 342.0, Moving Avg (100): 123.22
# Episode 252, Reward: 189.0, Moving Avg (100): 124.60
# Episode 253, Reward: 171.0, Moving Avg (100): 125.02
# Episode 254, Reward: 27.0, Moving Avg (100): 124.77
# Episode 255, Reward: 61.0, Moving Avg (100): 125.26
# Episode 256, Reward: 48.0, Moving Avg (100): 125.48
# Episode 257, Reward: 226.0, Moving Avg (100): 127.48
# Episode 258, Reward: 307.0, Moving Avg (100): 130.28
# Episode 259, Reward: 161.0, Moving Avg (100): 131.58
# Episode 260, Reward: 88.0, Moving Avg (100): 131.81
# Episode 261, Reward: 162.0, Moving Avg (100): 132.96
# Episode 262, Reward: 155.0, Moving Avg (100): 133.43
# Episode 263, Reward: 112.0, Moving Avg (100): 134.11
# Episode 264, Reward: 147.0, Moving Avg (100): 135.31
# Episode 265, Reward: 165.0, Moving Avg (100): 135.42
# Episode 266, Reward: 197.0, Moving Avg (100): 135.60
# Episode 267, Reward: 225.0, Moving Avg (100): 136.31
# Episode 268, Reward: 71.0, Moving Avg (100): 136.61
# Episode 269, Reward: 199.0, Moving Avg (100): 137.59
# Episode 270, Reward: 232.0, Moving Avg (100): 138.83
# Episode 271, Reward: 146.0, Moving Avg (100): 139.89
# Episode 272, Reward: 145.0, Moving Avg (100): 139.15
# Episode 273, Reward: 271.0, Moving Avg (100): 141.59
# Episode 274, Reward: 294.0, Moving Avg (100): 144.31
# Episode 275, Reward: 75.0, Moving Avg (100): 144.81
# Episode 276, Reward: 130.0, Moving Avg (100): 145.05
# Episode 277, Reward: 500.0, Moving Avg (100): 149.46
# Episode 278, Reward: 189.0, Moving Avg (100): 150.06
# Episode 279, Reward: 83.0, Moving Avg (100): 150.48
# Episode 280, Reward: 26.0, Moving Avg (100): 149.49
# Episode 281, Reward: 369.0, Moving Avg (100): 151.38
# Episode 282, Reward: 148.0, Moving Avg (100): 151.94
# Episode 283, Reward: 500.0, Moving Avg (100): 156.03
# Episode 284, Reward: 500.0, Moving Avg (100): 160.69
# Episode 285, Reward: 385.0, Moving Avg (100): 163.00
# Episode 286, Reward: 168.0, Moving Avg (100): 164.41
# Episode 287, Reward: 256.0, Moving Avg (100): 165.38
# Episode 288, Reward: 349.0, Moving Avg (100): 164.08
# Episode 289, Reward: 249.0, Moving Avg (100): 165.21
# Episode 290, Reward: 170.0, Moving Avg (100): 166.44
# Episode 291, Reward: 379.0, Moving Avg (100): 169.24
# Episode 292, Reward: 183.0, Moving Avg (100): 168.48
# Episode 293, Reward: 500.0, Moving Avg (100): 172.11
# Episode 294, Reward: 420.0, Moving Avg (100): 175.86
# Episode 295, Reward: 234.0, Moving Avg (100): 176.95
# Episode 296, Reward: 227.0, Moving Avg (100): 176.70
# Episode 297, Reward: 185.0, Moving Avg (100): 176.96
# Episode 298, Reward: 30.0, Moving Avg (100): 176.96
# Episode 299, Reward: 78.0, Moving Avg (100): 177.32
# Episode 300, Reward: 281.0, Moving Avg (100): 179.31
# Episode 301, Reward: 315.0, Moving Avg (100): 180.38
# Episode 302, Reward: 500.0, Moving Avg (100): 183.31
# Episode 303, Reward: 89.0, Moving Avg (100): 182.83
# Episode 304, Reward: 141.0, Moving Avg (100): 183.96
# Episode 305, Reward: 110.0, Moving Avg (100): 184.46
# Episode 306, Reward: 37.0, Moving Avg (100): 184.62
# Episode 307, Reward: 500.0, Moving Avg (100): 187.77
# Episode 308, Reward: 281.0, Moving Avg (100): 189.41
# Episode 309, Reward: 500.0, Moving Avg (100): 193.19
# Episode 310, Reward: 107.0, Moving Avg (100): 191.92
# Episode 311, Reward: 76.0, Moving Avg (100): 191.15
# Episode 312, Reward: 217.0, Moving Avg (100): 191.71
# Episode 313, Reward: 212.0, Moving Avg (100): 192.85
# Episode 314, Reward: 159.0, Moving Avg (100): 191.77
# Episode 315, Reward: 269.0, Moving Avg (100): 193.25
# Episode 316, Reward: 281.0, Moving Avg (100): 195.56
# Episode 317, Reward: 500.0, Moving Avg (100): 198.26
# Episode 318, Reward: 173.0, Moving Avg (100): 197.80
# Episode 319, Reward: 288.0, Moving Avg (100): 200.27
# Episode 320, Reward: 500.0, Moving Avg (100): 204.20
# Episode 321, Reward: 16.0, Moving Avg (100): 203.05
# Episode 322, Reward: 130.0, Moving Avg (100): 203.09
# Episode 323, Reward: 34.0, Moving Avg (100): 201.63
# Episode 324, Reward: 259.0, Moving Avg (100): 203.91
# Episode 325, Reward: 296.0, Moving Avg (100): 204.85
# Episode 326, Reward: 272.0, Moving Avg (100): 206.16
# Episode 327, Reward: 126.0, Moving Avg (100): 205.41
# Episode 328, Reward: 395.0, Moving Avg (100): 207.49
# Episode 329, Reward: 162.0, Moving Avg (100): 208.62
# Episode 330, Reward: 234.0, Moving Avg (100): 210.30
# Episode 331, Reward: 374.0, Moving Avg (100): 213.67
# Episode 332, Reward: 252.0, Moving Avg (100): 214.81
# Episode 333, Reward: 273.0, Moving Avg (100): 215.90
# Episode 334, Reward: 95.0, Moving Avg (100): 213.09
# Episode 335, Reward: 205.0, Moving Avg (100): 214.14
# Episode 336, Reward: 249.0, Moving Avg (100): 216.28
# Episode 337, Reward: 230.0, Moving Avg (100): 216.38
# Episode 338, Reward: 355.0, Moving Avg (100): 218.24
# Episode 339, Reward: 500.0, Moving Avg (100): 222.95
# Episode 340, Reward: 359.0, Moving Avg (100): 226.31
# Episode 341, Reward: 102.0, Moving Avg (100): 227.06
# Episode 342, Reward: 25.0, Moving Avg (100): 226.98
# Episode 343, Reward: 500.0, Moving Avg (100): 229.66
# Episode 344, Reward: 420.0, Moving Avg (100): 231.51
# Episode 345, Reward: 500.0, Moving Avg (100): 232.09
# Episode 346, Reward: 500.0, Moving Avg (100): 235.56
# Episode 347, Reward: 239.0, Moving Avg (100): 237.58
# Episode 348, Reward: 24.0, Moving Avg (100): 237.39
# Episode 349, Reward: 500.0, Moving Avg (100): 240.61
# Episode 350, Reward: 325.0, Moving Avg (100): 239.61
# Episode 351, Reward: 354.0, Moving Avg (100): 239.73
# Episode 352, Reward: 64.0, Moving Avg (100): 238.48
# Episode 353, Reward: 285.0, Moving Avg (100): 239.62
# Episode 354, Reward: 285.0, Moving Avg (100): 242.20
# Episode 355, Reward: 224.0, Moving Avg (100): 243.83
# Episode 356, Reward: 243.0, Moving Avg (100): 245.78
# Episode 357, Reward: 262.0, Moving Avg (100): 246.14
# Episode 358, Reward: 20.0, Moving Avg (100): 243.27
# Episode 359, Reward: 200.0, Moving Avg (100): 243.66
# Episode 360, Reward: 500.0, Moving Avg (100): 247.78
# Episode 361, Reward: 251.0, Moving Avg (100): 248.67
# Episode 362, Reward: 500.0, Moving Avg (100): 252.12
# Episode 363, Reward: 186.0, Moving Avg (100): 252.86
# Episode 364, Reward: 500.0, Moving Avg (100): 256.39
# Episode 365, Reward: 372.0, Moving Avg (100): 258.46
# Episode 366, Reward: 205.0, Moving Avg (100): 258.54
# Episode 367, Reward: 413.0, Moving Avg (100): 260.42
# Episode 368, Reward: 272.0, Moving Avg (100): 262.43
# Episode 369, Reward: 426.0, Moving Avg (100): 264.70
# Episode 370, Reward: 95.0, Moving Avg (100): 263.33
# Episode 371, Reward: 191.0, Moving Avg (100): 263.78
# Episode 372, Reward: 500.0, Moving Avg (100): 267.33
# Episode 373, Reward: 227.0, Moving Avg (100): 266.89
# Episode 374, Reward: 196.0, Moving Avg (100): 265.91
# Episode 375, Reward: 500.0, Moving Avg (100): 270.16
# Episode 376, Reward: 433.0, Moving Avg (100): 273.19
# Episode 377, Reward: 150.0, Moving Avg (100): 269.69
# Episode 378, Reward: 20.0, Moving Avg (100): 268.00
# Episode 379, Reward: 500.0, Moving Avg (100): 272.17
# Episode 380, Reward: 30.0, Moving Avg (100): 272.21
# Episode 381, Reward: 500.0, Moving Avg (100): 273.52
# Episode 382, Reward: 500.0, Moving Avg (100): 277.04
# Episode 383, Reward: 500.0, Moving Avg (100): 277.04
# Episode 384, Reward: 134.0, Moving Avg (100): 273.38
# Episode 385, Reward: 181.0, Moving Avg (100): 271.34
# Episode 386, Reward: 87.0, Moving Avg (100): 270.53
# Episode 387, Reward: 500.0, Moving Avg (100): 272.97
# Episode 388, Reward: 500.0, Moving Avg (100): 274.48
# Episode 389, Reward: 500.0, Moving Avg (100): 276.99
# Episode 390, Reward: 94.0, Moving Avg (100): 276.23
# Episode 391, Reward: 500.0, Moving Avg (100): 277.44
# Episode 392, Reward: 500.0, Moving Avg (100): 280.61
# Episode 393, Reward: 500.0, Moving Avg (100): 280.61
# Episode 394, Reward: 500.0, Moving Avg (100): 281.41
# Episode 395, Reward: 270.0, Moving Avg (100): 281.77
# Episode 396, Reward: 500.0, Moving Avg (100): 284.50
# Episode 397, Reward: 91.0, Moving Avg (100): 283.56
# Episode 398, Reward: 25.0, Moving Avg (100): 283.51
# Episode 399, Reward: 500.0, Moving Avg (100): 287.73
# Episode 400, Reward: 500.0, Moving Avg (100): 289.92
# Episode 401, Reward: 500.0, Moving Avg (100): 291.77
# Episode 402, Reward: 500.0, Moving Avg (100): 291.77
# Episode 403, Reward: 500.0, Moving Avg (100): 295.88
# Episode 404, Reward: 500.0, Moving Avg (100): 299.47
# Episode 405, Reward: 500.0, Moving Avg (100): 303.37
# Episode 406, Reward: 248.0, Moving Avg (100): 305.48
# Episode 407, Reward: 351.0, Moving Avg (100): 303.99
# Episode 408, Reward: 500.0, Moving Avg (100): 306.18
# Episode 409, Reward: 256.0, Moving Avg (100): 303.74
# Episode 410, Reward: 113.0, Moving Avg (100): 303.80
# Episode 411, Reward: 500.0, Moving Avg (100): 308.04
# Episode 412, Reward: 500.0, Moving Avg (100): 310.87
# Episode 413, Reward: 500.0, Moving Avg (100): 313.75
# Episode 414, Reward: 500.0, Moving Avg (100): 317.16
# Episode 415, Reward: 500.0, Moving Avg (100): 319.47
# Episode 416, Reward: 500.0, Moving Avg (100): 321.66
# Episode 417, Reward: 500.0, Moving Avg (100): 321.66
# Episode 418, Reward: 500.0, Moving Avg (100): 324.93
# Episode 419, Reward: 440.0, Moving Avg (100): 326.45
# Episode 420, Reward: 500.0, Moving Avg (100): 326.45
# Episode 421, Reward: 500.0, Moving Avg (100): 331.29
# Episode 422, Reward: 500.0, Moving Avg (100): 334.99
# Episode 423, Reward: 500.0, Moving Avg (100): 339.65
# Episode 424, Reward: 500.0, Moving Avg (100): 342.06
# Episode 425, Reward: 436.0, Moving Avg (100): 343.46
# Episode 426, Reward: 500.0, Moving Avg (100): 345.74
# Episode 427, Reward: 500.0, Moving Avg (100): 349.48
# Episode 428, Reward: 251.0, Moving Avg (100): 348.04
# Episode 429, Reward: 500.0, Moving Avg (100): 351.42
# Episode 430, Reward: 500.0, Moving Avg (100): 354.08
# Episode 431, Reward: 500.0, Moving Avg (100): 355.34
# Episode 432, Reward: 500.0, Moving Avg (100): 357.82
# Episode 433, Reward: 500.0, Moving Avg (100): 360.09
# Episode 434, Reward: 500.0, Moving Avg (100): 364.14
# Episode 435, Reward: 500.0, Moving Avg (100): 367.09
# Episode 436, Reward: 500.0, Moving Avg (100): 369.60
# Episode 437, Reward: 198.0, Moving Avg (100): 369.28
# Episode 438, Reward: 31.0, Moving Avg (100): 366.04
# Episode 439, Reward: 500.0, Moving Avg (100): 366.04
# Episode 440, Reward: 500.0, Moving Avg (100): 367.45
# Episode 441, Reward: 61.0, Moving Avg (100): 367.04
# Episode 442, Reward: 279.0, Moving Avg (100): 369.58
# Episode 443, Reward: 500.0, Moving Avg (100): 369.58
# Episode 444, Reward: 500.0, Moving Avg (100): 370.38
# Episode 445, Reward: 246.0, Moving Avg (100): 367.84
# Episode 446, Reward: 500.0, Moving Avg (100): 367.84
# Episode 447, Reward: 110.0, Moving Avg (100): 366.55
# Episode 448, Reward: 152.0, Moving Avg (100): 367.83
# Episode 449, Reward: 109.0, Moving Avg (100): 363.92
# Episode 450, Reward: 411.0, Moving Avg (100): 364.78
# Episode 451, Reward: 125.0, Moving Avg (100): 362.49
# Episode 452, Reward: 173.0, Moving Avg (100): 363.58
# Episode 453, Reward: 500.0, Moving Avg (100): 365.73
# Episode 454, Reward: 382.0, Moving Avg (100): 366.70
# Episode 455, Reward: 500.0, Moving Avg (100): 369.46
# Episode 456, Reward: 290.0, Moving Avg (100): 369.93
# Episode 457, Reward: 500.0, Moving Avg (100): 372.31
# Episode 458, Reward: 500.0, Moving Avg (100): 377.11
# Episode 459, Reward: 500.0, Moving Avg (100): 380.11
# Episode 460, Reward: 500.0, Moving Avg (100): 380.11
# Episode 461, Reward: 100.0, Moving Avg (100): 378.60
# Episode 462, Reward: 18.0, Moving Avg (100): 373.78
# Episode 463, Reward: 500.0, Moving Avg (100): 376.92
# Episode 464, Reward: 500.0, Moving Avg (100): 376.92
# Episode 465, Reward: 500.0, Moving Avg (100): 378.20
# Episode 466, Reward: 500.0, Moving Avg (100): 381.15
# Episode 467, Reward: 500.0, Moving Avg (100): 382.02
# Episode 468, Reward: 500.0, Moving Avg (100): 384.30
# Episode 469, Reward: 500.0, Moving Avg (100): 385.04
# Episode 470, Reward: 500.0, Moving Avg (100): 389.09
# Episode 471, Reward: 500.0, Moving Avg (100): 392.18
# Episode 472, Reward: 500.0, Moving Avg (100): 392.18
# Episode 473, Reward: 386.0, Moving Avg (100): 393.77
# Episode 474, Reward: 500.0, Moving Avg (100): 396.81
# Episode 475, Reward: 221.0, Moving Avg (100): 394.02
# Episode 476, Reward: 500.0, Moving Avg (100): 394.69
# Episode 477, Reward: 500.0, Moving Avg (100): 398.19
# Episode 478, Reward: 500.0, Moving Avg (100): 402.99
# Episode 479, Reward: 500.0, Moving Avg (100): 402.99
# Episode 480, Reward: 500.0, Moving Avg (100): 407.69
# Episode 481, Reward: 500.0, Moving Avg (100): 407.69
# Episode 482, Reward: 500.0, Moving Avg (100): 407.69
# Episode 483, Reward: 500.0, Moving Avg (100): 407.69
# Episode 484, Reward: 500.0, Moving Avg (100): 411.35
# Episode 485, Reward: 500.0, Moving Avg (100): 414.54
# Episode 486, Reward: 500.0, Moving Avg (100): 418.67
# Episode 487, Reward: 500.0, Moving Avg (100): 418.67
# Episode 488, Reward: 500.0, Moving Avg (100): 418.67
# Episode 489, Reward: 500.0, Moving Avg (100): 418.67
# Episode 490, Reward: 500.0, Moving Avg (100): 422.73
# Episode 491, Reward: 500.0, Moving Avg (100): 422.73
# Episode 492, Reward: 500.0, Moving Avg (100): 422.73
# Episode 493, Reward: 84.0, Moving Avg (100): 418.57
# Episode 494, Reward: 500.0, Moving Avg (100): 418.57
# Episode 495, Reward: 500.0, Moving Avg (100): 420.87
# Episode 496, Reward: 500.0, Moving Avg (100): 420.87
# Episode 497, Reward: 500.0, Moving Avg (100): 424.96
# Episode 498, Reward: 500.0, Moving Avg (100): 429.71
# Episode 499, Reward: 500.0, Moving Avg (100): 429.71
# Episode 500, Reward: 500.0, Moving Avg (100): 429.71
# Episode 501, Reward: 500.0, Moving Avg (100): 429.71
# Episode 502, Reward: 500.0, Moving Avg (100): 429.71
# Episode 503, Reward: 500.0, Moving Avg (100): 429.71
# Episode 504, Reward: 42.0, Moving Avg (100): 425.13
# Episode 505, Reward: 240.0, Moving Avg (100): 422.53
# Episode 506, Reward: 500.0, Moving Avg (100): 425.05
# Episode 507, Reward: 500.0, Moving Avg (100): 426.54
# Episode 508, Reward: 500.0, Moving Avg (100): 426.54
# Episode 509, Reward: 500.0, Moving Avg (100): 428.98
# Episode 510, Reward: 500.0, Moving Avg (100): 432.85
# Episode 511, Reward: 381.0, Moving Avg (100): 431.66
# Episode 512, Reward: 172.0, Moving Avg (100): 428.38
# Episode 513, Reward: 500.0, Moving Avg (100): 428.38
# Episode 514, Reward: 500.0, Moving Avg (100): 428.38
# Episode 515, Reward: 500.0, Moving Avg (100): 428.38
# Episode 516, Reward: 500.0, Moving Avg (100): 428.38
# Episode 517, Reward: 500.0, Moving Avg (100): 428.38
# Episode 518, Reward: 500.0, Moving Avg (100): 428.38
# Episode 519, Reward: 500.0, Moving Avg (100): 428.98
# Episode 520, Reward: 500.0, Moving Avg (100): 428.98
# Episode 521, Reward: 500.0, Moving Avg (100): 428.98
# Episode 522, Reward: 500.0, Moving Avg (100): 428.98
# Episode 523, Reward: 500.0, Moving Avg (100): 428.98
# Episode 524, Reward: 500.0, Moving Avg (100): 428.98
# Episode 525, Reward: 500.0, Moving Avg (100): 429.62
# Episode 526, Reward: 500.0, Moving Avg (100): 429.62
# Episode 527, Reward: 500.0, Moving Avg (100): 429.62
# Episode 528, Reward: 500.0, Moving Avg (100): 432.11
# Episode 529, Reward: 500.0, Moving Avg (100): 432.11
# Episode 530, Reward: 284.0, Moving Avg (100): 429.95
# Episode 531, Reward: 500.0, Moving Avg (100): 429.95
# Episode 532, Reward: 500.0, Moving Avg (100): 429.95
# Episode 533, Reward: 500.0, Moving Avg (100): 429.95
# Episode 534, Reward: 270.0, Moving Avg (100): 427.65
# Episode 535, Reward: 500.0, Moving Avg (100): 427.65
# Episode 536, Reward: 500.0, Moving Avg (100): 427.65
# Episode 537, Reward: 500.0, Moving Avg (100): 430.67
# Episode 538, Reward: 500.0, Moving Avg (100): 435.36
# Episode 539, Reward: 500.0, Moving Avg (100): 435.36
# Episode 540, Reward: 500.0, Moving Avg (100): 435.36
# Episode 541, Reward: 500.0, Moving Avg (100): 439.75
# Episode 542, Reward: 500.0, Moving Avg (100): 441.96
# Episode 543, Reward: 500.0, Moving Avg (100): 441.96
# Episode 544, Reward: 500.0, Moving Avg (100): 441.96
# Episode 545, Reward: 500.0, Moving Avg (100): 444.50
# Episode 546, Reward: 500.0, Moving Avg (100): 444.50
# Episode 547, Reward: 500.0, Moving Avg (100): 448.40
# Episode 548, Reward: 500.0, Moving Avg (100): 451.88
# Episode 549, Reward: 66.0, Moving Avg (100): 451.45
# Episode 550, Reward: 500.0, Moving Avg (100): 452.34
# Episode 551, Reward: 500.0, Moving Avg (100): 456.09
# Episode 552, Reward: 395.0, Moving Avg (100): 458.31
# Episode 553, Reward: 500.0, Moving Avg (100): 458.31
# Episode 554, Reward: 500.0, Moving Avg (100): 459.49
# Episode 555, Reward: 500.0, Moving Avg (100): 459.49
# Episode 556, Reward: 500.0, Moving Avg (100): 461.59
# Episode 557, Reward: 500.0, Moving Avg (100): 461.59
# Episode 558, Reward: 500.0, Moving Avg (100): 461.59
# Episode 559, Reward: 500.0, Moving Avg (100): 461.59
# Episode 560, Reward: 500.0, Moving Avg (100): 461.59
# Episode 561, Reward: 500.0, Moving Avg (100): 465.59
# Episode 562, Reward: 500.0, Moving Avg (100): 470.41
# Episode 563, Reward: 500.0, Moving Avg (100): 470.41
# Episode 564, Reward: 500.0, Moving Avg (100): 470.41
# Episode 565, Reward: 500.0, Moving Avg (100): 470.41
# Episode 566, Reward: 339.0, Moving Avg (100): 468.80
# Episode 567, Reward: 500.0, Moving Avg (100): 468.80
# Episode 568, Reward: 500.0, Moving Avg (100): 468.80
# Episode 569, Reward: 500.0, Moving Avg (100): 468.80
# Episode 570, Reward: 500.0, Moving Avg (100): 468.80
# Episode 571, Reward: 500.0, Moving Avg (100): 468.80
# Episode 572, Reward: 500.0, Moving Avg (100): 468.80
# Episode 573, Reward: 500.0, Moving Avg (100): 469.94
# Episode 574, Reward: 500.0, Moving Avg (100): 469.94
# Episode 575, Reward: 500.0, Moving Avg (100): 472.73
# Episode 576, Reward: 500.0, Moving Avg (100): 472.73
# Episode 577, Reward: 500.0, Moving Avg (100): 472.73
# Episode 578, Reward: 500.0, Moving Avg (100): 472.73
# Episode 579, Reward: 500.0, Moving Avg (100): 472.73
# Episode 580, Reward: 500.0, Moving Avg (100): 472.73
# Episode 581, Reward: 500.0, Moving Avg (100): 472.73
# Episode 582, Reward: 500.0, Moving Avg (100): 472.73
# Episode 583, Reward: 500.0, Moving Avg (100): 472.73
# Episode 584, Reward: 500.0, Moving Avg (100): 472.73
# Episode 585, Reward: 500.0, Moving Avg (100): 472.73
# Episode 586, Reward: 500.0, Moving Avg (100): 472.73
# Episode 587, Reward: 500.0, Moving Avg (100): 472.73
# Episode 588, Reward: 500.0, Moving Avg (100): 472.73
# Episode 589, Reward: 500.0, Moving Avg (100): 472.73
# Episode 590, Reward: 500.0, Moving Avg (100): 472.73
# Episode 591, Reward: 500.0, Moving Avg (100): 472.73
# Episode 592, Reward: 500.0, Moving Avg (100): 472.73
# Episode 593, Reward: 500.0, Moving Avg (100): 476.89
# [+] Environment solved in 593 episodes!

# %% [markdown]
# #render

# %%
import imageio
from IPython.display import HTML
from base64 import b64encode

env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, _ = env.reset()
done = False

frames = []

while not done:
    action, _, _ = agent.select_action(obs)
    obs, _, terminated, truncated, _ = env.step(action)
    done = terminated or truncated
    frame = env.render()
    frames.append(frame)

env.close()

# ذخیره ویدیو
video_path = "/content/cartpole_render.mp4"
imageio.mimsave(video_path, frames, fps=30)

# نمایش ویدیو در Colab
mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""<video width=400 controls><source src="{data_url}" type="video/mp4"></video>""")
# Out:
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# <video width=400 controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>
